# %%
import os
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
DERIVED_DATA_PATH = "../data/derived_data/item_altars/"
os.makedirs(DERIVED_DATA_PATH, exist_ok=True)

# %%
altar = mpimg.imread("../data/original_data/isaac_graphics/levelitem_001_itemaltar.png")
plt.imshow(altar)

# %%
plt.imshow(altar[5:28,2:29,:])
mpimg.imsave(DERIVED_DATA_PATH + "/item_altar_001.png", altar[5:28,2:29,:])

# %%
plt.imshow(altar[59:80,106:134,:])
mpimg.imsave(DERIVED_DATA_PATH + "item_altar_002.png", altar[59:80,106:134,:])

# %%
plt.imshow(altar[109:,59:85,:])
mpimg.imsave(DERIVED_DATA_PATH + "item_altar_003.png", altar[109:,59:85,:])

# %%
plt.imshow(altar[109:,107:133,:])
mpimg.imsave(DERIVED_DATA_PATH + "item_altar_004.png", altar[109:,107:133,:])

# %%
plt.imshow(altar[92:,3:45,:])
mpimg.imsave(DERIVED_DATA_PATH + "item_altar_005.png", altar[92:,3:45,:])

# %%
plt.imshow(altar[44:80,3:45,:])
mpimg.imsave(DERIVED_DATA_PATH + "item_altar_006.png", altar[44:80,3:45,:])

# %%
plt.imshow(altar[50:80,49:96,:])
mpimg.imsave(DERIVED_DATA_PATH + "item_altar_007.png", altar[50:80,49:96,:])
