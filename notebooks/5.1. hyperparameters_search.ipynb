# %%
import tensorflow as tf
from tensorflow.keras import layers, Sequential
import numpy as np
import tqdm
import itertools
import random
import uuid
import json
import os
# Out:
# 2023-08-02 17:45:01.980300: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-02 17:45:02.104230: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-02 17:45:02.108487: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-08-02 17:45:02.108499: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-08-02 17:45:02.128837: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-08-02 17:45:02.613109: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-08-02 17:45:02.613226: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-08-02 17:45:02.613237: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
BATCH_SIZE = 32
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 716
RANDOM_SEED = 0

DATA_PATH = "../data/derived_data/data_augmented/"
RESULTS_PATH = "./hps_search_results/"

# %%
random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %%
hps_grid = dict(
    conv2d_1_filters = [16],
    conv2d_1_kernel = [3],
    conv2d_2_filters = [32],
    conv2d_2_kernel = [3],
    conv2d_3_filters = [64],
    conv2d_3_kernel = [3],
    conv2d_4_filters = [64],
    conv2d_4_kernel = [3],
    dense_1_units = [128],
    pooling = [layers.MaxPooling2D],
    optimizer = [
        tf.keras.optimizers.Adam,
        # tf.keras.optimizers.RMSprop,
    ],
    learning_rate = [0.001]
)

# %%
params = list(itertools.product(*hps_grid.values()))
hps_combs = [dict(zip(hps_grid.keys(),params_sample)) for params_sample in params]

# %%
random.shuffle(hps_combs)

# %%
def vgg_module(filters=16, kernel=3, conv_padding='same', activation='relu', pool_size=(2, 2), pool_padding='valid'):
    return Sequential([
        layers.Conv2D(filters, kernel, padding=conv_padding, activation=activation),
        layers.Conv2D(filters, kernel, padding=conv_padding, activation=activation),
        layers.MaxPooling2D(pool_size=pool_size, padding=pool_padding),
    ])
 


def mobile_module(filters=16, kernel=3, conv_padding='same', activation='relu', pool_size=(2, 2), pool_padding='same'):
    return Sequential([
        layers.Conv2D(filters, kernel, padding=conv_padding, activation=activation),
        layers.MaxPooling2D(pool_size=pool_size, padding=pool_padding),
    ])

# %%
def define_model(hps_comb):

    pooling = hps_comb['pooling']

    model = Sequential([
        layers.Rescaling(1./255, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        vgg_module(),
        layers.BatchNormalization(),
        vgg_module(),
        layers.BatchNormalization(),
        layers.Flatten(),
        layers.Dense(1024, activation='relu'),
        layers.Dense(NUM_CLASSES)
    ])

    model.compile(
        optimizer=hps_comb['optimizer'](learning_rate=hps_comb['learning_rate']),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=['accuracy'],
    )

    return model


def train_model(
        model,
        train_ds,
        val_ds,
        test_ds,
        checkpoint_filepath=None, 
        epochs=1000
    ):

    # Define callbacks
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
    )

    
    # model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    #     filepath=checkpoint_filepath,
    #     save_weights_only=True,
    #     monitor='val_accuracy',
    #     save_best_only=True
    # )
    
    # Train model
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=[
            # early_stopping,
            # model_checkpoint,
        ],
        verbose='auto',
    )
    
    results = history.history

    test_loss, test_acc = model.evaluate(test_ds)

    results['test_loss'] = test_loss
    results['test_acc'] = test_acc
    
    return results


def run_hps_search(train_ds, val_ds, test_ds, output_path):
    hps_search_id = uuid.uuid4()

    output_path = f'{output_path}/{hps_search_id}/'
    os.makedirs(output_path, exist_ok=True)

    for hps_comb in tqdm.tqdm(hps_combs):
        print(hps_comb)
        hps_comb_id = uuid.uuid4()

        model = define_model(hps_comb)

        results = train_model(
            model, 
            train_ds=train_ds,
            val_ds=val_ds,
            test_ds=test_ds,
        )

        for k,v in hps_comb.items():
            results[k] = str(v)

        with open(f'{output_path}/{hps_comb_id}.json', 'w') as f:
            json.dump(results, f)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_PATH,
    labels="inferred",
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    validation_split=0.3,
    subset="training",
    image_size=(IMG_WIDTH, IMG_HEIGHT),
    shuffle=True,
    seed=0,
    interpolation='nearest'
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_PATH,
    labels="inferred",
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    validation_split=0.3,
    subset="validation",
    image_size=(IMG_WIDTH, IMG_HEIGHT),
    shuffle=True,
    seed=0,
    interpolation='nearest'
)

val_batches = tf.data.experimental.cardinality(val_ds)
test_ds = val_ds.take(val_batches // 2)
val_ds = val_ds.skip(val_batches // 2)
# Out:
# Found 716 files belonging to 716 classes.
# Using 502 files for training.
# Found 716 files belonging to 716 classes.
# Using 214 files for validation.
# 2023-08-02 17:45:03.347587: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-08-02 17:45:03.347663: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-08-02 17:45:03.347941: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mizunno-laptop): /proc/driver/nvidia/version does not exist
# 2023-08-02 17:45:03.348275: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.axis("off")

# %%
run_hps_search(train_ds, val_ds, test_ds, RESULTS_PATH)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# {'conv2d_1_filters': 16, 'conv2d_1_kernel': 3, 'conv2d_2_filters': 32, 'conv2d_2_kernel': 3, 'conv2d_3_filters': 64, 'conv2d_3_kernel': 3, 'conv2d_4_filters': 64, 'conv2d_4_kernel': 3, 'dense_1_units': 128, 'pooling': <class 'keras.layers.pooling.max_pooling2d.MaxPooling2D'>, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>, 'learning_rate': 0.001}
# Epoch 1/1000
# 16/16 [==============================] - 5s 294ms/step - loss: 8.6806 - accuracy: 0.0000e+00 - val_loss: 6.6901 - val_accuracy: 0.0000e+00
# Epoch 2/1000
# 16/16 [==============================] - 5s 286ms/step - loss: 6.5865 - accuracy: 0.0000e+00 - val_loss: 6.6725 - val_accuracy: 0.0000e+00
# Epoch 3/1000
# 16/16 [==============================] - 5s 279ms/step - loss: 6.5684 - accuracy: 0.0000e+00 - val_loss: 6.7652 - val_accuracy: 0.0000e+00
# Epoch 4/1000
# 16/16 [==============================] - 5s 279ms/step - loss: 6.5127 - accuracy: 0.0000e+00 - val_loss: 7.1132 - val_accuracy: 0.0000e+00
# Epoch 5/1000
# 16/16 [==============================] - 5s 282ms/step - loss: 6.4567 - accuracy: 0.0020 - val_loss: 7.3735 - val_accuracy: 0.0000e+00
# Epoch 6/1000
# 16/16 [==============================] - 5s 307ms/step - loss: 5.3768 - accuracy: 0.0737 - val_loss: 14.3250 - val_accuracy: 0.0000e+00
# Epoch 24/1000
# 16/16 [==============================] - 5s 306ms/step - loss: 4.9298 - accuracy: 0.1355 - val_loss: 16.8535 - val_accuracy: 0.0000e+00
# Epoch 25/1000
# 16/16 [==============================] - 5s 305ms/step - loss: 4.3343 - accuracy: 0.2311 - val_loss: 18.8755 - val_accuracy: 0.0000e+00
# Epoch 26/1000
# 16/16 [==============================] - 5s 306ms/step - loss: 3.5942 - accuracy: 0.3625 - val_loss: 20.7415 - val_accuracy: 0.0000e+00
# Epoch 27/1000
# 16/16 [==============================] - 5s 306ms/step - loss: 2.7573 - accuracy: 0.5398 - val_loss: 22.1749 - val_accuracy: 0.0000e+00
# Epoch 28/1000
# 16/16 [==============================] - 5s 309ms/step - loss: 2.0251 - accuracy: 0.6892 - val_loss: 22.4082 - val_accuracy: 0.0000e+00
# Epoch 29/1000
# 16/16 [==============================] - 5s 300ms/step - loss: 1.4132 - accuracy: 0.7849 - val_loss: 22.2607 - val_accuracy: 0.0000e+00
# Epoch 30/1000
# 16/16 [==============================] - 5s 299ms/step - loss: 0.9613 - accuracy: 0.8725 - val_loss: 23.9078 - val_accuracy: 0.0000e+00
# Epoch 31/1000
# 16/16 [==============================] - 5s 304ms/step - loss: 0.6458 - accuracy: 0.9263 - val_loss: 23.4009 - val_accuracy: 0.0000e+00
# Epoch 32/1000
# 16/16 [==============================] - 5s 301ms/step - loss: 0.4515 - accuracy: 0.9422 - val_loss: 24.7394 - val_accuracy: 0.0000e+00
# Epoch 33/1000
# 16/16 [==============================] - 5s 299ms/step - loss: 0.3094 - accuracy: 0.9602 - val_loss: 22.7165 - val_accuracy: 0.0000e+00
# Epoch 34/1000
# 16/16 [==============================] - 5s 298ms/step - loss: 0.2656 - accuracy: 0.9681 - val_loss: 24.2762 - val_accuracy: 0.0000e+00
# Epoch 35/1000
# 16/16 [==============================] - 5s 295ms/step - loss: 0.1728 - accuracy: 0.9841 - val_loss: 24.1294 - val_accuracy: 0.0000e+00
# Epoch 36/1000
# 16/16 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9861
#   0%|          | 0/1 [02:54<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/mizunno/Projects/TBOI_item_detector/notebooks/5. hyperparameters_search.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> run_hps_search(train_ds, val_ds, test_ds, RESULTS_PATH)
#
# /home/mizunno/Projects/TBOI_item_detector/notebooks/5. hyperparameters_search.ipynb Cell 11 in run_hps_search(train_ds, val_ds, test_ds, output_path)
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=75'>76</a> hps_comb_id = uuid.uuid4()
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=77'>78</a> model = define_model(hps_comb)
# ---> <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=79'>80</a> results = train_model(
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=80'>81</a>     model,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=81'>82</a>     train_ds=train_ds,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=82'>83</a>     val_ds=val_ds,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=83'>84</a>     test_ds=test_ds,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=84'>85</a> )
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=86'>87</a> for k,v in hps_comb.items():
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=87'>88</a>     results[k] = str(v)
#
# /home/mizunno/Projects/TBOI_item_detector/notebooks/5. hyperparameters_search.ipynb Cell 11 in train_model(model, train_ds, val_ds, test_ds, checkpoint_filepath, epochs)
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=31'>32</a> early_stopping = tf.keras.callbacks.EarlyStopping(
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=32'>33</a>     monitor='val_loss',
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=33'>34</a>     patience=5,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=34'>35</a>     restore_best_weights=True,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=35'>36</a> )
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=38'>39</a> # model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=39'>40</a> #     filepath=checkpoint_filepath,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=40'>41</a> #     save_weights_only=True,
#    (...)
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=44'>45</a>
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=45'>46</a> # Train model
# ---> <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=46'>47</a> history = model.fit(
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=47'>48</a>     train_ds,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=48'>49</a>     validation_data=val_ds,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=49'>50</a>     epochs=epochs,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=50'>51</a>     callbacks=[
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=51'>52</a>         # early_stopping,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=52'>53</a>         # model_checkpoint,
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=53'>54</a>     ],
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=54'>55</a>     verbose='auto',
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=55'>56</a> )
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=57'>58</a> results = history.history
#      <a href='vscode-notebook-cell:/home/mizunno/Projects/TBOI_item_detector/notebooks/5.%20hyperparameters_search.ipynb#X13sZmlsZQ%3D%3D?line=59'>60</a> test_loss, test_acc = model.evaluate(test_ds)
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/keras/engine/training.py:1606, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1591 if getattr(self, "_eval_data_handler", None) is None:
#    1592     self._eval_data_handler = data_adapter.get_data_handler(
#    1593         x=val_x,
#    1594         y=val_y,
#    (...)
#    1604         steps_per_execution=self._steps_per_execution,
#    1605     )
# -> 1606 val_logs = self.evaluate(
#    1607     x=val_x,
#    1608     y=val_y,
#    1609     sample_weight=val_sample_weight,
#    1610     batch_size=validation_batch_size or batch_size,
#    1611     steps=validation_steps,
#    1612     callbacks=callbacks,
#    1613     max_queue_size=max_queue_size,
#    1614     workers=workers,
#    1615     use_multiprocessing=use_multiprocessing,
#    1616     return_dict=True,
#    1617     _use_cached_eval_dataset=True,
#    1618 )
#    1619 val_logs = {
#    1620     "val_" + name: val for name, val in val_logs.items()
#    1621 }
#    1622 epoch_logs.update(val_logs)
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/keras/engine/training.py:1947, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1943 with tf.profiler.experimental.Trace(
#    1944     "test", step_num=step, _r=1
#    1945 ):
#    1946     callbacks.on_test_batch_begin(step)
# -> 1947     tmp_logs = self.test_function(iterator)
#    1948     if data_handler.should_sync:
#    1949         context.async_wait()
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/Projects/TBOI_item_detector/env/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
