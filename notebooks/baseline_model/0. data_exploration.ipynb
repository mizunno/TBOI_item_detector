# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob

# %%
images_path = "../../data/original_data/items/"

# %%
images_paths = glob.glob(images_path + "*")
images_paths
# Out:
# ['../../data/original_data/items/3 Dollar Bill.png',
#  '../../data/original_data/items/Rotten Tomato.png',
#  '../../data/original_data/items/Lusty Blood.png',
#  '../../data/original_data/items/Lil Chest.png',
#  '../../data/original_data/items/Leprosy.png',
#  '../../data/original_data/items/Psy Fly.png',
#  '../../data/original_data/items/Steven (Item).png',
#  '../../data/original_data/items/Immaculate Heart.png',
#  '../../data/original_data/items/Black Hole.png',
#  '../../data/original_data/items/Sharp Key.png',
#  '../../data/original_data/items/Spindown Dice.png',
#  '../../data/original_data/items/Blood Rights.png',
#  "../../data/original_data/items/Dad's Ring.png",
#  '../../data/original_data/items/Dark Arts.png',
#  '../../data/original_data/items/Flat Stone.png',
#  "../../data/original_data/items/Mom's Box.png",
#  '../../data/original_data/items/A Snack.png',
#  '../../data/original_data/items/Binky.png',
#  '../../data/original_data/items/Rainbow Baby.png',
# ...

# %%
img = mpimg.imread(images_paths[1])
imgplot = plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (32, 32, 4)

# %%
images_paths[0]
# Out:
# '../../data/original_data/items/3 Dollar Bill.png'

# %%
# Check if all images are shaped as (32, 32, 4)
for img_path in images_paths:
    img_shape = mpimg.imread(img_path).shape
    if img_shape != (32, 32, 4):
        print(img_path, img_shape)
# Out:
# ../../data/original_data/items/Seraphim.png (24, 30, 4)

# %%
# Check if pixels are from 0 to 255 as in RGB images
for img_path in images_paths:
    img = mpimg.imread(img_path)
    
    if img.min() < 0 or img.max() > 255:
        print(img_path)

# %%
print("Number of items: ", len(images_paths))
# Out:
# Number of items:  716
