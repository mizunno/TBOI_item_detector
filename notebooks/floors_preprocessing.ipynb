# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
FLOOR_PATHS = "../data/original_data/floors"
DERIVED_FLOOR_PATHS = "../data/derived_data/floors"

# %%
img = Image.open(f"{FLOOR_PATHS}/0a_library.png").convert("RGB")

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=520x468>

# %%
img_arr = np.array(img)

# %%
w = 234
h = 156

# %%
for i in range(3):
    print((h*i),(h*(i+1)))
    plt.imshow(img_arr[(h*i):(h*(i+1)),:w,:])
    plt.show()
    plt.imshow(img_arr[(h*i):(h*(i+1)),w:2*w,:])
    plt.show()
# Out:
# 0 156
# 156 312
# 312 468
